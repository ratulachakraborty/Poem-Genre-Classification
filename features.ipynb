# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: appnope==0.1.3 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (0.1.3)
# Requirement already satisfied: asttokens==2.2.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: backcall==0.2.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: certifi==2022.12.7 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==3.1.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: click==8.1.3 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: comm==0.1.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: contourpy==1.0.7 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.6 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: empath==0.89 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.89)
# Requirement already satisfied: executing==1.2.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: fonttools==4.39.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (4.39.2)
# Requirement already satisfied: idna==3.4 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (3.4)
# Requirement already satisfied: importlib-metadata==6.1.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (6.1.0)
# Requirement already satisfied: importlib-resources==5.12.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (5.12.0)
# Requirement already satisfied: ipykernel==6.21.3 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (6.21.3)
# Requirement already satisfied: ipython==8.11.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (8.11.0)
# Requirement already satisfied: jedi==0.18.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (1.2.0)
# Requirement already satisfied: jupyter_client==8.0.3 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (8.0.3)
# Requirement already satisfied: jupyter_core==5.3.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (5.3.0)
# Requirement already satisfied: kiwisolver==1.4.4 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (1.4.4)
# Requirement already satisfied: MarkupSafe==2.1.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.1.6)
# Requirement already satisfied: nest-asyncio==1.5.6 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (1.5.6)
# Requirement already satisfied: nltk==3.8.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (3.8.1)
# Requirement already satisfied: numpy==1.24.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (1.24.2)
# Requirement already satisfied: packaging==23.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (23.0)
# Requirement already satisfied: pandas==1.5.3 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (1.5.3)
# Requirement already satisfied: parso==0.8.3 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (0.7.5)
# Requirement already satisfied: Pillow==9.4.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (9.4.0)
# Requirement already satisfied: platformdirs==3.1.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (3.1.1)
# Requirement already satisfied: prompt-toolkit==3.0.38 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (3.0.38)
# Requirement already satisfied: psutil==5.9.4 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (0.2.2)
# Requirement already satisfied: Pygments==2.14.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (2.14.0)
# Requirement already satisfied: pyparsing==3.0.9 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.8.2)
# Requirement already satisfied: pytz==2022.7.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (2022.7.1)
# Requirement already satisfied: pyzmq==25.0.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 47)) (25.0.1)
# Requirement already satisfied: regex==2022.10.31 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 48)) (2022.10.31)
# Requirement already satisfied: requests==2.28.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 49)) (2.28.2)
# Requirement already satisfied: seaborn==0.12.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (0.12.2)
# Requirement already satisfied: six==1.16.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 51)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 52)) (0.6.2)
# Requirement already satisfied: textblob==0.17.1 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 53)) (0.17.1)
# Requirement already satisfied: tornado==6.2 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 54)) (6.2)
# Requirement already satisfied: tqdm==4.65.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 55)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 56)) (5.9.0)
# Requirement already satisfied: urllib3==1.26.15 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (1.26.15)
# Requirement already satisfied: wcwidth==0.2.6 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (0.2.6)
# Requirement already satisfied: zipp==3.15.0 in ./poem-genre-venv/lib/python3.9/site-packages (from -r requirements.txt (line 59)) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.corpus import stopwords
import re, unicodedata
from empath import Empath
from textblob import TextBlob 
import pandas as pd
import string

# %%
import features

# %% [markdown]
# Reading Data

# %%
train = pd.read_csv("all.csv")
train.head()
# Out:
#                                     author  \
# 0                      WILLIAM SHAKESPEARE
# 1  DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                           THOMAS BASTARD
# 3                           EDMUND SPENSER
# 4                        RICHARD BARNFIELD
#
#                                              content  \
# 0  Let the bird of loudest lay\r\nOn the sole Ara...
# 1  Sir Charles into my chamber coming in,\r\nWhen...
# 2  Our vice runs beyond all that old men saw,\r\n...
# 3  Lo I the man, whose Muse whilome did maske,\r\...
# 4  Long have I longd to see my love againe,\r\nSt...
#
#                                  poem_name          age                  type
# 0               The Phoenix and the Turtle  Renaissance  Mythology & Folklore
# 1                 An Epilogue to the Above  Renaissance  Mythology & Folklore
# 2                       Book 7, Epigram 42  Renaissance  Mythology & Folklore
# 3  from The Faerie Queene: Book I, Canto I  Renaissance  Mythology & Folklore
# 4                                Sonnet 16  Renaissance  Mythology & Folklore

# %% [markdown]
# Cleaning data

# %%
train['clean_content'] = train["content"].apply(lambda x: features.tokenize(features.remove_stop_words(features.convert_case(features.clean_text(x)))))
train.head(5)
# Out:
#                                     author  \
# 0                      WILLIAM SHAKESPEARE
# 1  DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                           THOMAS BASTARD
# 3                           EDMUND SPENSER
# 4                        RICHARD BARNFIELD
#
#                                              content  \
# 0  Let the bird of loudest lay\r\nOn the sole Ara...
# 1  Sir Charles into my chamber coming in,\r\nWhen...
# 2  Our vice runs beyond all that old men saw,\r\n...
# 3  Lo I the man, whose Muse whilome did maske,\r\...
# 4  Long have I longd to see my love againe,\r\nSt...
#
#                                  poem_name          age                  type  \
# 0               The Phoenix and the Turtle  Renaissance  Mythology & Folklore
# 1                 An Epilogue to the Above  Renaissance  Mythology & Folklore
# 2                       Book 7, Epigram 42  Renaissance  Mythology & Folklore
# 3  from The Faerie Queene: Book I, Canto I  Renaissance  Mythology & Folklore
# 4                                Sonnet 16  Renaissance  Mythology & Folklore
#
#                                        clean_content
# 0  [[let, bird, loudest, lay, sole, arabian, tree...
# 1  [[sir, charles, chamber, coming, writing, fair...
# 2  [[vice, runs, beyond, old, men, saw, far, auth...
# 3  [[lo, man, whose, muse, whilome, maske, time, ...
# 4  [[long, longd, see, love, againe, still, wisht...

# %%
def feature_extract(poem):
    features={}  
    features['avg_token_length'] = features.average_token_count(poem)
    features['token_count'] = features.length(poem)
    features['largest_token'] = features.largest_token(poem)
    features['empath'] = features.empath_finder(poem)
    features['sentiment'] = features.get_sentiment(poem)
    return features

# %%
f=open( r"C:\Users\user\Desktop\RATULA\MINOR 2\feature_poem5.csv",'w+',encoding='utf-8')
csvWriter = csv.writer(f)
csvWriter.writerow(["Average_token count", "length", "largest_token","empath values","sentiment","type"])
df=pd.read_csv(r"C:/Users/user/Desktop/RATULA/MINOR 2/all.csv")

for index,row in df1.iterrows():
    csvWriter.writerow([average_token_count(row['content']), length(row['content']), largest_token(row['content']), empath_finder(row['content']), get_sentiment(row['content']),row['type']])
